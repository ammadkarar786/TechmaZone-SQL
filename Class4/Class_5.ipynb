# %% [markdown]
# 1. Find Rock Albums List the names of all artists who have an album with "Rock" anywhere in the title.

# %% [markdown]
# 2. Artists with Many Songs Show the names of artists who have more than 4000 songs (tracks) across all their albums combined.

# %% [markdown]
# 3. Purchases Made in 2010 For every purchase made in the year 2010, show the customer's first name, last name, the song they bought, and the date of the invoice.

# %% [markdown]
# 4. Expensive Music Genres Find which music genres have an average song price greater than $1.00.

# %% [markdown]
# 5. Busy Support Staff List the first and last names of employees who are responsible for supporting 3 or more customers.

# %% [markdown]
# 6. Metallica Playlists Show the names of playlists that contain at least one song by the artist "Metallica," along with the name of that specific song.

# %% [markdown]
# 7. High-Spending Countries Which countries have customers who have spent a total of more than $100 on invoices? Show the country name and the total amount spent.

# %% [markdown]
# 8. Long Songs by Media Type Count how many songs are longer than 200,000 milliseconds (about 3.3 minutes), grouped by their media type (e.g., MPEG audio file, Protected AAC).

# %% [markdown]
# 9. Who Reports to Whom? Create a list showing each employee's full name alongside the full name of the manager they report to.

# %% [markdown]
# 10. Top Earning Genres Find the music genres that have generated more than $50 in total sales revenue. List them from highest revenue to lowest.
